# %% [markdown]
# # Load data

# %%
#load dependencies
import numpy as np
from IPython.display import Image
from matplotlib import gridspec
import pandas as pd
import numpy as np
import pymc as pm
import matplotlib.pyplot as plt
import seaborn as sns


sns.set(style='white', palette='Set2', font='arial', font_scale=1.0, rc=None)

df=pd.read_csv('planningPR_evidence_queries.csv') #load data
#print means of each key variable



#Convert percentage of each key variable to number of successes out of 8 choices
#The purpose of this is to transform the data such that it can be modelled by a binomial likelihood

br_bias=df['bias_baserate']*4
df2=df[df['bias_baserate']>0.51]
n_subjects2=len(df2)
PR_evidence2=df2['PR']*6
df['bias_baserate']=df['bias_baserate']-0.5
# import bambi as bmb
# model = bmb.Model("PR ~ bias_baserate", df)
# fitted = model.fit(tune=2000, draws=2000)
# import arviz as az
# az.summary(fitted)

import statsmodels.api as sm
import numpy as np
Y = df['PR']
X = baserate_bias
X = sm.add_constant(X)
model = sm.OLS(Y,X)
results = model.fit()
print(results.summary())
print(results.params)
print('')

n_subjects = n_subjects
subjects= [*range(n_subjects)]





print(df.mean())

# # Print 0.1*SD of PR Evidence to define the ROPE
# print('ROPE of PR EVIDENCE: {}'.format(0.1*df['PR'].std()))
# n_subjects=len(df)
# PR_evidence=df['PR']*6
# print(n_subjects)

# rr_map=df['rwd_reval']*4
# tr_changed_map=df['tr_reval']*4
sns.set(style='white', font='arial', font_scale=2.1, rc={'figure.figsize':(12,10)})


# fig, axes = plt.subplots(2, 1)

# x=sns.countplot(x="PR", palette='Blues',data=df,ax=axes[0],order = [x/6 for x in range(0,7)])

# y=sns.kdeplot(data=df_posterior, x=('posterior', 'omega'),ax=axes[1],fill=True,alpha=1,color='blue')
# axes[0].set_ylabel('Participants')
# axes[0].bar(df["PR"].unique()*6, df["PR"].value_counts(sort=False), color=['gray', 'blue', 'blue','blue', 'red','red'])
# axes[0].set_xlabel('Forward \u2190 Consistency of choice \u2192 Backward')
# axes[0].set_xlim(-0.5, 6.5)
# # axes[0].xaxis.set_major_formatter('{x:.1f}')
# axes[0].set_title('Humans Prefer Backward Planning in a Diverging Environment\n')

# axes[0].axvline(3,color='black',linewidth=6.0)
# axes[1].set_xlim(-0.06,1.06)
# axes[1].set_ylim
# axes[1].set_ylabel('Probability Density')
# axes[1].set_xlabel('Forward \u2190 Modal consistency of choice \u2192 Backward')
# axes[1].axvline(0.5,color='black',linewidth=6.0)
# axes[1].axhline(y=0,xmin=0.54,xmax=0.71,color='yellow',linewidth=10.0)
# plt.sca(axes[1])
# plt.yticks([5,10,15])
# plt.xticks([0,0.17,0.33,0.5,0.67,0.83,1.00])
# axes[0].margins(x=0)
# axes[1].margins(x=0)
# axes[0].set_xticklabels(['{:.2f}'.format(float(t.get_text())) for t in axes[0].get_xticklabels()])

# axes[1].set_xticklabels(['{:.2f}'.format(float(t.get_text())) for t in axes[1].get_xticklabels()])

# fig.subplots_adjust(hspace=0.7)

# plt.savefig('study2_PRevidence.png',dpi=300)

# plt.show()

# sns.set(style='white', font='arial', font_scale=2, rc={'figure.figsize':(7,5)})
# fig, ax = plt.subplots()
# #sigmoid function
# def sigmoid(x):
#     return 1 / (1 + math.exp(-x))

sns.set(style='white', font='arial', font_scale=2, rc={'figure.figsize':(7,5)})

#load data
df_new=pd.DataFrame()
df_new['Revaluation Score']=df['rwd_reval'].values.tolist()+df['tr_reval'].values.tolist()
df_new['']=['Learnt Map']*len(df)+['Changed Map']*len(df)                              
#plot transition revaluation performance

ax=sns.countplot(data=df_new, y="Revaluation Score",hue="",palette='Greys',orient='v')
plt.xlabel('Participants')

ax.set_ylim(-0.5,4.5)
ax.set_yticklabels(['{:.2f}'.format(float(t.get_text())) for t in ax.get_yticklabels()])

ax.set_ylim(-0.5,4.5)
ax.set_yticklabels(['{:.2f}'.format(float(t.get_text())) for t in ax.get_yticklabels()])

plt.axhline(2,color='black',linewidth=4.0)
sns.move_legend(ax, "lower right",frameon=False)

# Change the font size of the legend text
leg = ax.get_legend()
for text in leg.get_texts():
    text.set_fontsize(20)

# Change the size and spacing of the legend bars
for patch in leg.get_patches():
    patch.set_height(10)
    patch.set_width(20)
    patch.set_x(patch.get_x() + 30) # adjust the y position of the bars


# for tick in ax.get_xaxis().get_major_ticks():
#     tick.set_pad(8.)

plt.ylabel('Choice Accuracy')
plt.title('Predictive Representations Check')

plt.tight_layout()

plt.savefig('study2_tr_Reval.png',dpi=300)
plt.show()
# Print 0.1*SD of PR Evidence to define the ROPE
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     PR   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.281
# Date:                Thu, 06 Apr 2023   Prob (F-statistic):              0.263
# Time:                        11:58:24   Log-Likelihood:                 3.1168
# No. Observations:                  50   AIC:                            -2.234
# Df Residuals:                      48   BIC:                             1.590
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.5986      0.034     17.827      0.000       0.531       0.666
# bias_baserate     0.2688      0.237      1.132      0.263      -0.209       0.746
# ==============================================================================
# Omnibus:                        2.725   Durbin-Watson:                   2.245
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.150
# Skew:                          -0.507   Prob(JB):                        0.341
# Kurtosis:                       3.057   Cond. No.                         7.24
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# const            0.598604
# bias_baserate    0.268761
# dtype: float64
#
# PR               0.606667
# tree             0.620000
# north            0.680000
# bell             0.660000
# train            0.580000
# snorkel          0.460000
# tophat           0.640000
# bias_baserate    0.030000
# rwd_reval        0.860000
# tr_reval         0.530000
# dtype: float64
# /var/folders/t8/0vpf6dyn0q111yjvx8dbs7dc0000gn/T/ipykernel_24232/2819558777.py:51: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(df.mean())

# %%
print(az.summary(fitted, hdi_prob=0.95))
# Out:
#                 mean     sd  hdi_2.5%  hdi_97.5%  mcse_mean  mcse_sd  \
# Intercept      0.599  0.034     0.532      0.665      0.000    0.000
# bias_baserate  0.268  0.246    -0.219      0.744      0.003    0.002
# PR_sigma       0.235  0.024     0.190      0.286      0.000    0.000
#
#                ess_bulk  ess_tail  r_hat
# Intercept       10962.0    6394.0    1.0
# bias_baserate    9603.0    5838.0    1.0
# PR_sigma        10349.0    5977.0    1.0

# %% [markdown]
# # Fit Model for Hypothesis 1: Evidence for PR-based Planning
#
# Below we fit the beta-binomial described in text to choice data for Variable 1, which defines the number of times participants chose in line with PR-based planning. If omega, the mode of the group distribution, is estimated to be significantly greater than 0.5 (no evidence of PR-based planning), then we conclude evidence for our main hypothesis.
#
# We followed Kruschke’s (2014) guidelines to derive the ROPE, wherein we took the standard deviation of the percentage of times subjects chose in line with PR-based planning and multiplied this value by 0.1 , which was 0.18, and multiplied this by 0.1, to define effects that are too small to be considered significant. We then rounded this up to 0.2 to make it even a bit more conservative than Kruschke’s (2014) recommendation. We use this ROPE for all subsequent analyses.
#
# Note below, we fit the same model to the two subsequent manipulation checks, except include different variables (specifically, variables 3 and 5 as described in the preregistration).

# %%
n_subjects = n_subjects
subjects= [*range(n_subjects)]
with pm.Model() as hierarchical_model:

    omega = pm.Beta('omega', 1., 1.)
    kappa_minus2 = pm.Gamma('kappa_minus2', 1.105125 , 0.1051249)
    kappa = pm.Deterministic('kappa', kappa_minus2 + 2)
    
    theta = pm.Beta('theta', alpha=omega*(kappa-2)+1, beta=(1-omega)*(kappa-2)+1, shape=n_subjects)


    y = pm.Binomial('y',n=6,p=theta[subjects], observed=PR_evidence) 
    
with hierarchical_model:
    trace_main = pm.sample(draws=4000, target_accept=0.99,init='adapt_diag')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [omega, kappa_minus2, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:55&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 76 seconds.

# %%
n_subjects = n_subjects2
subjects= [*range(n_subjects2)]
with pm.Model() as hierarchical_model:

    omega = pm.Beta('omega', 1., 1.)
    kappa_minus2 = pm.Gamma('kappa_minus2', 1.105125 , 0.1051249)
    kappa = pm.Deterministic('kappa', kappa_minus2 + 2)
    
    theta = pm.Beta('theta', alpha=omega*(kappa-2)+1, beta=(1-omega)*(kappa-2)+1, shape=n_subjects2)


    y = pm.Binomial('y',n=6,p=theta[subjects], observed=PR_evidence2) 
    
with hierarchical_model:
    trace_main2 = pm.sample(draws=4000, target_accept=0.99,init='adapt_diag')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [omega, kappa_minus2, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:51&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 72 seconds.

# %%
import arviz as az
az.summary(trace_main,var_names=['omega'])
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.598  0.049   0.509    0.691      0.001      0.0    5661.0    6300.0
#
#        r_hat
# omega    1.0

# %%
import arviz as az
az.summary(trace_main2,var_names=['omega'])
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.744  0.099   0.569    0.945      0.001    0.001    4648.0    4616.0
#
#        r_hat
# omega    1.0

# %%
contrast=trace_main2.posterior.omega.values-trace_main.posterior.omega.values
import arviz as az
az.summary(contrast)
# Out:
#     mean    sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  r_hat
# x  0.146  0.11  -0.053    0.362      0.002    0.001    4950.0    5324.0    1.0

# %%
df_posterior=trace_main.to_dataframe()
print(df_posterior[('posterior', 'omega')])
print(df_posterior.to_csv('posterior_model.csv'))
# Out:
# 0        0.634739
# 1        0.597707
# 2        0.613003
# 3        0.618289
# 4        0.616408
#            ...
# 15995    0.704235
# 15996    0.650443
# 15997    0.612524
# 15998    0.646075
# 15999    0.676016
# Name: (posterior, omega), Length: 16000, dtype: float64
# None

# %%
contrast_brbias=trace_main.posterior.omega-trace.posterior.omega

# %%
import arviz as az
az.plot_posterior(
    contrast_brbias,
#     var_names=['omega'],
    hdi_prob=0.95,
    rope=[-0.001,0.001],
    figsize=[5,2]
);

# plt.savefig('omega_PRevidence_over_brbias.png', bbox_inches='tight',  dpi=300)
plt.show()

az.summary(contrast_brbias, ['omega'])
# Out:
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.099  0.058  -0.012    0.207      0.001    0.001    1582.0    3187.0
#
#        r_hat
# omega    1.0

# %% [markdown]
# ## Posterior distribution for group-level tendency to choose in line with PR-based planning
#
# As you see below, the parameter omega defining the group-level tendency to choose in line with PR-based planning was significantly greater than the null value of 0.5. Specifically, the posterior highest density interval does not contain any values in the pre-defined region of practical equivalence, defining values similar-enough to 0.5 to be considered null effect sizes.

# %%
import arviz as az
az.plot_posterior(
    trace_main,
    var_names=['omega'],
    hdi_prob=0.95,
    rope=[0.48,0.52],
    figsize=[5,2]
);
plt.title('PR Effect')
plt.savefig('omega_PRevidence_posterior_betabinomial.png', bbox_inches='tight',  dpi=300)
plt.show()

az.summary(trace_main, ['omega'])
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/arviz/data/io_pymc3_3x.py:98: FutureWarning: Using `from_pymc3` without the model will be deprecated in a future release. Not using the model will return less accurate and less useful results. Make sure you use the model argument or call from_pymc3 within a model context.
#   warnings.warn(
# Got error No model on context stack. trying to find log_likelihood in translation.
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.629  0.045   0.547    0.714      0.001      0.0    4613.0    6121.0
#
#        r_hat
# omega    1.0

# %% [markdown]
# # Fit model for manipulation check 1: Bias for high base-rate action?

# %%
n_subjects = n_subjects
subjects= [*range(n_subjects)]
with pm.Model() as hierarchical_model:

    omega = pm.Beta('omega', 1., 1.)
    kappa_minus2 = pm.Gamma('kappa_minus2', 1.105125 , 0.1051249)
    kappa = pm.Deterministic('kappa', kappa_minus2 + 2)
    
    theta = pm.Beta('theta', alpha=omega*(kappa-2)+1, beta=(1-omega)*(kappa-2)+1, shape=n_subjects)


    y = pm.Binomial('y',n=4,p=theta[subjects], observed=br_bias) 
    
with hierarchical_model:
    trace = pm.sample(draws=4000, target_accept=0.99)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [omega, kappa_minus2, theta]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:59&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 79 seconds.

# %%
az.summary(trace,var_names=['omega'])
# Out:
#        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.53  0.039   0.457    0.606      0.001    0.001    2638.0    4952.0
#
#        r_hat
# omega    1.0

# %%
df_posterior_distal=trace.to_dataframe()
print()

# %% [markdown]
# ## Plot posterior for omega: The highest-density interval (black line) in the posterior does not include 0.3 or 0.7.
#
# Manipulation check passed!

# %%
sns.set(style='white', font='arial', font_scale=2.3, rc={'figure.figsize':(9.5,5)})
fig, ax = plt.subplots()

x=sns.kdeplot(data=df_posterior_distal, x=('posterior', 'omega'),fill=True,alpha=1,color="gray")

y=sns.kdeplot(data=df_posterior_distal, x=('posterior', 'omega'),fill=True,alpha=1,color="gray")
ax.set_ylabel('Probability Density')
ax.set_xlabel('Low \u2190 Modal Base-Rate Bias \u2192 High')
ax.set_xlim(0,1.0)
ax.set_title('Bias Check')
ax.axhline(y=0,xmin=0.457,xmax=0.606,color='yellow',linewidth=10.0)



ax.set_xticklabels(['{:.2f}'.format(float(t.get_text())) for t in ax.get_xticklabels()])

plt.tight_layout()

plt.savefig('study2_action_distal_bias.png',dpi=300)
plt.show()
# Out:
# /var/folders/t8/0vpf6dyn0q111yjvx8dbs7dc0000gn/T/ipykernel_24232/3762283280.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['{:.2f}'.format(float(t.get_text())) for t in ax.get_xticklabels()])

# %%
import arviz as az
az.plot_posterior(
    trace,
    var_names=['omega'],
    hdi_prob=0.95,
    rope=[0.68,0.72],
    figsize=[5,2]
);
plt.title('Base Rate Effect')
plt.savefig('omega_BRbaserate_posterior_betabinomial.png', bbox_inches='tight',  dpi=300)
plt.show()

az.summary(trace, ['omega'])
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.
# Got error No model on context stack. trying to find log_likelihood in translation.
#         mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  ess_bulk  ess_tail  \
# omega  0.531  0.036   0.462    0.599      0.001    0.001     750.0    1478.0
#
#        r_hat
# omega   1.01

# %% [markdown]
# # Transition and Reward Revaluation: Load and visualize data

# %%
import numpy as np
import pandas as pd
import math
from matplotlib.pyplot import figure
figure(figsize=(2, 2), dpi=300)

#sigmoid function
def sigmoid(x):
    return 1 / (1 + math.exp(-x))

#load data

#plot transition revaluation performance
df1=df['tr_reval']*4
ax=df1.plot.hist(bins=20, alpha=0.5)

#plot reward revaluation performance
df2=df['rwd_reval']*4
ax=df2.plot.hist(bins=20, alpha=0.5)


plt.legend(['trn reval', 'rwd reval'])
plt.show()

# %%
cost_TR=df['tr_reval']*4-df['rwd_reval']*4
subjects= [*range(n_subjects)]

with pm.Model() as hierarchical_model:
    eps = pm.HalfNormal('error', sigma=10)

    reval_diff = pm.Normal('reval_diff_intercept', mu=0, sigma=10)

    y = pm.Normal("reval_effect",mu=reval_diff, sigma=eps,observed=cost_TR)
    
with hierarchical_model:
    diff_reval = pm.sample(draws=4000, target_accept=0.999,init='adapt_diag')
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [error, reval_diff_intercept]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:12&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 36 seconds.

# %%
import arviz as az
az.summary(diff_reval)
# Out:
#                        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# reval_diff_intercept -1.321  0.249  -1.797   -0.863      0.003    0.002
# error                 1.731  0.184   1.397    2.078      0.002    0.002
#
#                       ess_bulk  ess_tail  r_hat
# reval_diff_intercept    6259.0    7046.0    1.0
# error                   7132.0    7260.0    1.0

# %% [markdown]
# ## Calculate cost of Transition Revaluation and subtract it from cost of Reward Revaluation for each subject

# %%
figure(figsize=(2, 2), dpi=300)

cost_TR=df['rwd_reval']-df['tr_reval']
cost_RR=1-df['rwd_reval']
effect_TR=cost_TR-cost_RR #subtract cost of reward reval from cost of transition revaluation
df3=pd.DataFrame()
df3['effect_TR']=effect_TR

ax=df3.plot.hist(bins=20, alpha=0.5)
plt.show()
df4=df3[df3['effect_TR']<0]

# %% [markdown]
# ## Fit model to determine if the cost of transition revaluation is significantly greater than the effect of reward evaluation

# %%
with pm.Model() as model_effect_TR:  # model specifications in PyMC3 are wrapped in a with-statement
    # Define priors
    sigma = pm.HalfCauchy("sigma", beta=10, testval=1.0)
    mu = pm.Normal("mu", 0, sigma=20)

    # Define likelihood
    likelihood = pm.Normal("y", mu=mu, sigma=sigma, observed=effect_TR)
    
with model_effect_TR:
    trace_effect_TR = pm.sample(draws=4000, target_accept=0.99,init='adapt_diag')
# Out:
# /var/folders/bb/qt1m2y_s49v7r03yds1dm_0w0000gn/T/ipykernel_59531/1056306411.py:10: FutureWarning: In v4.0, pm.sample will return an `arviz.InferenceData` object instead of a `MultiTrace` by default. You can pass return_inferencedata=True or return_inferencedata=False to be safe and silence this warning.
#   trace_effect_TR = pm.sample(draws=4000, target_accept=0.99,init='adapt_diag')
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:07&lt;00:00 Sampling 4 chains, 0 divergences]
#     </div>
# Sampling 4 chains for 1_000 tune and 4_000 draw iterations (4_000 + 16_000 draws total) took 20 seconds.

# %%
az.plot_posterior(
    trace_effect_TR,
    var_names=['mu'],
    hdi_prob=0.95,
    rope=[-.02,0.02],
    figsize=[5,2]
);
plt.title('Transition Revaluation Effect')
plt.savefig('effect_TR.png', bbox_inches='tight',  dpi=300)
plt.show()
# Out:
# Got error No model on context stack. trying to find log_likelihood in translation.

# %%
('')
